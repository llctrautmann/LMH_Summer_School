# %% [markdown]
# This example is motivated from an example where a carefully chose snapshot of data was used to prove that global temperatures are not increasing with time.
#
# You will solve linear regression (ax+b) for two snapshots of data to see if there is an average increase of tempearture with time or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def linear_regression_normal_equation(X,y):
    ones = np.ones((X.shape[0],1))
    
    X = np.append(ones, X, axis=1)
    
    W = np.dot(np.linalg.inv(np.dot(X.T,X)), np.dot(X.T,y))
        
    return (X@W,W)

# %%
df=pd.read_csv('globalTemp.csv')

# %%
x = df['Year'].to_numpy()
y = df['Actual Temp'].to_numpy()

plt.rcParams['figure.figsize'] = [15, 15]
plt.plot(x,y)

# %%
x = x[:,np.newaxis]
y = y[:,np.newaxis]

# %%
x.shape
# Out:
# (137, 1)

# %%
out = linear_regression_normal_equation(x,y)

# %%
plt.rcParams['figure.figsize'] = [15, 15]

plt.plot(x,y,'b',x,out[0],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x12727c0d0>,
#  <matplotlib.lines.Line2D at 0x12727c100>]

# %%
df=df[(df['Year']>1943) & (df['Year']<1975)]
x = df['Year'].to_numpy()
y = df['Actual Temp'].to_numpy()

# %%
x = x[:,np.newaxis]
y = y[:,np.newaxis]

# %%
out = linear_regression_normal_equation(x,y)

# %%
plt.rcParams['figure.figsize'] = [15, 15]

plt.plot(x,y,'b',x,out[0],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x1272ed480>,
#  <matplotlib.lines.Line2D at 0x1272ed4b0>]
