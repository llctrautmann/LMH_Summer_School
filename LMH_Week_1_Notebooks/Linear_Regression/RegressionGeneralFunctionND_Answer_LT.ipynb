# %% [markdown]
# # Homework 4: Linear Regression in 2D

# %%
#Linear Regression for general functions
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
def normal_equation(basis,x,x2,y):
    X = []
    basis = basis
    
    X1_vectorised = np.reshape(X1, (X1.shape[0]*X1.shape[1]))
    X2_vectorised = np.reshape(X2, (X2.shape[0]*X2.shape[1]))
    Y_vectorised = np.reshape(Y, (Y.shape[0]*Y.shape[1]))
    
    
    for i in range(basis+1):
        for j in range(basis+1):
            X.append(X1_vectorised**i * X2_vectorised**j)
    
    
    X = np.array(X).T
    
    W = np.dot(np.linalg.inv(np.dot(X.T,X)), np.dot(X.T,Y_vectorised))
    
    Yhat = np.reshape(X@W, (Y.shape[0],Y.shape[1]))
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')


    
    surf = ax.plot_surface(X1, X2, Yhat, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
    
    return None

# %%
pi=math.pi

fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1.001,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=np.exp(X1)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/420315634.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
Yhat = normal_equation(7,X1,X2,Y)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/67913697.py:22: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Example 2

# %%
pi=math.pi

fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=np.cos(2*pi*X1)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/890580837.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
normal_equation(7,X1,X2,Y)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/67913697.py:22: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=(X1**2)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/4097123113.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
normal_equation(6,X1,X2,Y)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/67913697.py:22: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=(X1>0)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/1988928719.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
normal_equation(7,X1,X2,Y)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/67913697.py:22: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=np.exp(X1**5)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/1689666025.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
normal_equation(7,X1,X2,Y)
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_90444/67913697.py:22: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
