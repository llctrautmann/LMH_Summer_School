# %% [markdown]
# Part 1: Implement logistic regression with Stochatic Gradient decent
#
# Part 2: Implement logistic regression with SGD with momentum

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plotClass(X,y,p):
    plt.figure()
    for i in range(y.shape[1]):
        if y[0,i]==0:
            plt.plot(X[0,i],X[1,i],'r'+p)
        else:
            plt.plot(X[0,i],X[1,i],'b'+p)
            
    plt.show()

# %%
num_data=100 # data points per class

x1=np.random.randn(2,num_data)+4
x0=np.random.randn(2,num_data)

y1=np.ones((1,num_data))
y0=np.zeros((1,num_data))

X=np.concatenate((x1,x0),axis=1)
y=np.concatenate((y1,y0), axis=1)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 200)
# (1, 200)

# %%
#stochastic Gradient Decent

# Functions
def sigmoid(z):
    return 1/(1 + np.exp(-z))
    
def linear(w,x,b):
    return w@x + b

def loss(y,yhat):
    return np.sum(-y * np.log(yhat)-(1-y)*np.log(1-yhat),axis =1)




# Initialise our weights randomly. FYI - This should equal the number of features squared
w = np.random.randn(y.shape[0],X.shape[0])

b = 0

ls = []

lr = 1e-4
epochs = 100000

# %%
w.shape
# Out:
# (1, 2)

# %%
# We now need to iteratively calculate our loss, calulate our gradients and take a step towards better weights.

lr = 1e-4
epochs = 100000



# An iteration here is called an "epoch"
for epoch in range(epochs):
    # First step is to calculate the loss for the current weights
    z = linear(w,X,b)
    yhat = sigmoid(z)
    losses = loss(y, yhat)


    ls.append(losses) # Save the loss to plot later. (Ideally we would plot this every epoch to check the loss is going down)

    # Backward Pass

    djdz = yhat - y

    djdw = djdz @ X.T

    w -= lr*djdw
    b -= lr*djdb # This step requires some claification. CLARIFICATION: the gradient formula is not solvable as a closed solution so we use gradient decent take the gardient at any point and move in the opposite direction.  

w.shape
# Out:
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_24345/550211256.py:11: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-y * np.log(yhat)-(1-y)*np.log(1-yhat),axis =1)
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_24345/550211256.py:11: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(-y * np.log(yhat)-(1-y)*np.log(1-yhat),axis =1)
# /var/folders/r9/9kmctj5907z_qfw6hp7s7bb40000gn/T/ipykernel_24345/550211256.py:5: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-z))
# (1, 2)

# %%
plotClass(X,yhat>0.5,"x")

# %%
num_data=100 # data points per class

x1=np.random.randn(2,num_data)+4
x0=np.random.randn(2,num_data)

y1=np.ones((1,num_data))
y0=np.zeros((1,num_data))

X=np.concatenate((x1,x0),axis=1)
y=np.concatenate((y1,y0), axis=1)
# plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 200)
# (1, 200)

# %%
X = X.T

print(y.shape)
# Out:
# (1, 200)

# %%
class StochasticGradientDecent:
    def __init__(self,features,targets,weights,basis = 1,lr=1e-4,epoch=100000): # features is the X here, targets the y
        self.features = features
        self._targets = targets

        self.sample = features.shape[0]
        self._feature_dim = features.shape[1]

        assert self.sample == targets.shape[0], "[Sample Size] Shape mismatch"

    @staticmethod
    def sigmoid(z):
        return 1/(1 + np.exp(-z))
    
    @staticmethod
    def linear(weights,features):
        return w@x + b

    @staticmethod
    def loss(y,yhat):
        return np.sum(-y * np.log(yhat)-(1-y)*np.log(1-yhat),axis =1)

# %%
test = np.random.randn((3 + 1) ** 2, 1)

# %%
test.shape
# Out:
# (16, 1)

# %%
# Note: Dimension [0,:,:,:] will remove the first dimension. It does the same job as does the funtion np.squeeze
