# %% [markdown]
# Part 1: Find a linear classifier using logistic regression to classify the data
#
# Part 2: Plot the decsion boundary along with the data
#
# Part 3: Plot the normal of the decision boundary

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plotClass(X,y,p):
    plt.figure()
    for i in range(y.shape[1]):
        if y[0,i]==0:
            plt.plot(X[0,i],X[1,i],'r'+p)
        else:
            plt.plot(X[0,i],X[1,i],'b'+p)
            
    plt.show()

# %%
num_data=100 # data points per class

x1=np.random.randn(2,num_data)+4
x0=np.random.randn(2,num_data)

y1=np.ones((1,num_data))
y0=np.zeros((1,num_data))

X=np.concatenate((x1,x0),axis=1)
y=np.concatenate((y1,y0), axis=1)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 200)
# (1, 200)
